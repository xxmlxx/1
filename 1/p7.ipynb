# %%
from pgmpy.models import BayesianModel

cancer_model = BayesianModel([('Pollution', 'Cancer'), 
                              ('Smoker', 'Cancer'),
                              ('Cancer', 'Xray'),
                              ('Cancer', 'Dyspnoea')])

# %%
cancer_model.nodes()
# Out:
# NodeView(('Pollution', 'Cancer', 'Smoker', 'Xray', 'Dyspnoea'))

# %%
cancer_model.edges()
# Out:
# OutEdgeView([('Pollution', 'Cancer'), ('Cancer', 'Xray'), ('Cancer', 'Dyspnoea'), ('Smoker', 'Cancer')])

# %%
cancer_model.get_cpds()
# Out:
# []

# %%
from pgmpy.factors.discrete import TabularCPD

cpd_poll = TabularCPD(variable='Pollution', variable_card=2,
                      values=[[0.9], [0.1]])
cpd_smoke = TabularCPD(variable='Smoker', variable_card=2,
                       values=[[0.3], [0.7]])
cpd_cancer = TabularCPD(variable='Cancer', variable_card=2,
                        values=[[0.03, 0.05, 0.001, 0.02],
                                [0.97, 0.95, 0.999, 0.98]],
                        evidence=['Smoker', 'Pollution'],
                        evidence_card=[2, 2])
cpd_xray = TabularCPD(variable='Xray', variable_card=2,
                      values=[[0.9, 0.2], [0.1, 0.8]],
                      evidence=['Cancer'], evidence_card=[2])
cpd_dysp = TabularCPD(variable='Dyspnoea', variable_card=2,
                      values=[[0.65, 0.3], [0.35, 0.7]],
                      evidence=['Cancer'], evidence_card=[2])

# %%
cancer_model.add_cpds(cpd_poll, cpd_smoke, cpd_cancer, cpd_xray, cpd_dysp)

cancer_model.check_model()
# Out:
# True

# %%
cancer_model.is_active_trail('Pollution', 'Smoker')
# Out:
# False

# %%
cancer_model.is_active_trail('Pollution', 'Smoker', observed=['Cancer'])
# Out:
# True

# %%
cancer_model.get_cpds()
# Out:
# [<TabularCPD representing P(Pollution:2) at 0x2df6d47d6a0>,
#  <TabularCPD representing P(Smoker:2) at 0x2df6d47d668>,
#  <TabularCPD representing P(Cancer:2 | Smoker:2, Pollution:2) at 0x2df6d47d630>,
#  <TabularCPD representing P(Xray:2 | Cancer:2) at 0x2df6d47d6d8>,
#  <TabularCPD representing P(Dyspnoea:2 | Cancer:2) at 0x2df4df89438>]

# %%
print(cancer_model.get_cpds('Pollution'))
print(cancer_model.get_cpds('Smoker'))
print(cancer_model.get_cpds('Xray'))
print(cancer_model.get_cpds('Dyspnoea'))
print(cancer_model.get_cpds('Cancer'))
# Out:
# ╒═════════════╤═════╕
# │ Pollution_0 │ 0.9 │
# ├─────────────┼─────┤
# │ Pollution_1 │ 0.1 │
# ╘═════════════╧═════╛
# ╒══════════╤═════╕
# │ Smoker_0 │ 0.3 │
# ├──────────┼─────┤
# │ Smoker_1 │ 0.7 │
# ╘══════════╧═════╛
# ╒════════╤══════════╤══════════╕
# │ Cancer │ Cancer_0 │ Cancer_1 │
# ├────────┼──────────┼──────────┤
# │ Xray_0 │ 0.9      │ 0.2      │
# ├────────┼──────────┼──────────┤
# │ Xray_1 │ 0.1      │ 0.8      │
# ╘════════╧══════════╧══════════╛
# ╒════════════╤══════════╤══════════╕
# │ Cancer     │ Cancer_0 │ Cancer_1 │
# ├────────────┼──────────┼──────────┤
# │ Dyspnoea_0 │ 0.65     │ 0.3      │
# ├────────────┼──────────┼──────────┤
# │ Dyspnoea_1 │ 0.35     │ 0.7      │
# ╘════════════╧══════════╧══════════╛
# ╒═══════════╤═════════════╤═════════════╤═════════════╤═════════════╕
# │ Smoker    │ Smoker_0    │ Smoker_0    │ Smoker_1    │ Smoker_1    │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Pollution │ Pollution_0 │ Pollution_1 │ Pollution_0 │ Pollution_1 │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Cancer_0  │ 0.03        │ 0.05        │ 0.001       │ 0.02        │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Cancer_1  │ 0.97        │ 0.95        │ 0.999       │ 0.98        │
# ╘═══════════╧═════════════╧═════════════╧═════════════╧═════════════╛

# %%
print("Local Independencies for X Ray :",cancer_model.local_independencies('Xray'))
print("Local Independencies for Pollution :",cancer_model.local_independencies('Pollution'))
print("Local Independencies for Smoker :",cancer_model.local_independencies('Smoker'))
print("Local Independencies for Dyspnoea :",cancer_model.local_independencies('Dyspnoea'))
print("Local Independencies for Cancer :",cancer_model.local_independencies('Cancer'))
# Out:
# Local Independencies for X Ray : (Xray _|_ Pollution, Dyspnoea, Smoker | Cancer)
# Local Independencies for Pollution : (Pollution _|_ Cancer, Xray, Dyspnoea, Smoker)
# Local Independencies for Smoker : (Smoker _|_ Xray, Cancer, Pollution, Dyspnoea)
# Local Independencies for Dyspnoea : (Dyspnoea _|_ Pollution, Xray, Smoker | Cancer)
# Local Independencies for Cancer : (Cancer _|_ Xray, Dyspnoea | Pollution, Smoker)

# %%
cancer_model.get_independencies()
# Out:
# (Pollution _|_ Smoker)
# (Pollution _|_ Xray, Dyspnoea | Cancer)
# (Pollution _|_ Dyspnoea | Cancer, Xray)
# (Pollution _|_ Xray | Cancer, Dyspnoea)
# (Pollution _|_ Xray, Dyspnoea | Cancer, Smoker)
# (Pollution _|_ Dyspnoea | Cancer, Xray, Smoker)
# (Pollution _|_ Xray | Cancer, Dyspnoea, Smoker)
# (Smoker _|_ Pollution)
# (Smoker _|_ Xray, Dyspnoea | Cancer)
# (Smoker _|_ Dyspnoea | Cancer, Xray)
# (Smoker _|_ Xray, Dyspnoea | Cancer, Pollution)
# (Smoker _|_ Xray | Cancer, Dyspnoea)
# (Smoker _|_ Dyspnoea | Pollution, Cancer, Xray)
# (Smoker _|_ Xray | Cancer, Pollution, Dyspnoea)
# (Xray _|_ Pollution, Dyspnoea, Smoker | Cancer)
# (Xray _|_ Dyspnoea, Smoker | Cancer, Pollution)
# (Xray _|_ Pollution, Smoker | Cancer, Dyspnoea)
# (Xray _|_ Pollution, Dyspnoea | Cancer, Smoker)
# (Xray _|_ Smoker | Cancer, Pollution, Dyspnoea)
# (Xray _|_ Dyspnoea | Cancer, Pollution, Smoker)
# (Xray _|_ Pollution | Cancer, Dyspnoea, Smoker)
# (Dyspnoea _|_ Xray, Pollution, Smoker | Cancer)
# (Dyspnoea _|_ Pollution, Smoker | Cancer, Xray)
# (Dyspnoea _|_ Xray, Smoker | Cancer, Pollution)
# (Dyspnoea _|_ Xray, Pollution | Cancer, Smoker)
# (Dyspnoea _|_ Smoker | Pollution, Cancer, Xray)
# (Dyspnoea _|_ Pollution | Cancer, Xray, Smoker)
# (Dyspnoea _|_ Xray | Cancer, Pollution, Smoker)

# %%
from pgmpy.inference import VariableElimination
cancer_infer = VariableElimination(cancer_model)

q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1})
print(q['Cancer'])
# Out:
# ╒══════════╤═══════════════╕
# │ Cancer   │   phi(Cancer) │
# ╞══════════╪═══════════════╡
# │ Cancer_0 │        0.0029 │
# ├──────────┼───────────────┤
# │ Cancer_1 │        0.9971 │
# ╘══════════╧═══════════════╛
# c:\users\harsh\appdata\local\programs\python\python37\lib\site-packages\pgmpy\factors\discrete\DiscreteFactor.py:586: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi.values = phi.values[slice_]

# %%
q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1,'Pollution': 1})
print(q['Cancer'])
# Out:
# ╒══════════╤═══════════════╕
# │ Cancer   │   phi(Cancer) │
# ╞══════════╪═══════════════╡
# │ Cancer_0 │        0.0200 │
# ├──────────┼───────────────┤
# │ Cancer_1 │        0.9800 │
# ╘══════════╧═══════════════╛

# %%
import numpy as np
from urllib.request import urlopen
import urllib
import matplotlib.pyplot as plt 
import seaborn as sns 
import sklearn as skl
import pandas as pd

# %%
Cleveland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
np.set_printoptions(threshold=np.nan)
names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'heartdisease']
heartDisease = pd.read_csv(urlopen(Cleveland_data_URL), names = names)
heartDisease.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  heartdisease
# 0    ?             0
# 1    ?             0
# 2    ?             0
# 3    6             0
# 4    ?             0

# %%
del heartDisease['ca']
del heartDisease['slope']
del heartDisease['thal']
del heartDisease['oldpeak']

heartDisease = heartDisease.replace('?', np.nan)
heartDisease.dtypes
# Out:
# age              int64
# sex              int64
# cp               int64
# trestbps        object
# chol            object
# fbs             object
# restecg         object
# thalach         object
# exang           object
# heartdisease     int64
# dtype: object

# %%
heartDisease.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'heartdisease'],
#       dtype='object')

# %%
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator

model = BayesianModel([('age', 'trestbps'), ('age', 'fbs'), ('sex', 'trestbps'), ('sex', 'trestbps'), 
                       ('exang', 'trestbps'),('trestbps','heartdisease'),('fbs','heartdisease'),
                      ('heartdisease','restecg'),('heartdisease','thalach'),('heartdisease','chol')])


model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
print(model.get_cpds('age'))
# Out:
# ╒═════════╤════════════╕
# │ age(28) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(29) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(30) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(31) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(32) │ 0.0153257  │
# ├─────────┼────────────┤
# │ age(33) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(34) │ 0.0153257  │
# ├─────────┼────────────┤
# │ age(35) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(36) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(37) │ 0.0306513  │
# ├─────────┼────────────┤
# │ age(38) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(39) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(40) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(41) │ 0.0383142  │
# ├─────────┼────────────┤
# │ age(42) │ 0.0268199  │
# ├─────────┼────────────┤
# │ age(43) │ 0.0421456  │
# ├─────────┼────────────┤
# │ age(44) │ 0.0268199  │
# ├─────────┼────────────┤
# │ age(45) │ 0.0229885  │
# ├─────────┼────────────┤
# │ age(46) │ 0.045977   │
# ├─────────┼────────────┤
# │ age(47) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(48) │ 0.0613027  │
# ├─────────┼────────────┤
# │ age(49) │ 0.0421456  │
# ├─────────┼────────────┤
# │ age(50) │ 0.045977   │
# ├─────────┼────────────┤
# │ age(51) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(52) │ 0.0574713  │
# ├─────────┼────────────┤
# │ age(53) │ 0.0383142  │
# ├─────────┼────────────┤
# │ age(54) │ 0.0842912  │
# ├─────────┼────────────┤
# │ age(55) │ 0.0536398  │
# ├─────────┼────────────┤
# │ age(56) │ 0.0306513  │
# ├─────────┼────────────┤
# │ age(57) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(58) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(59) │ 0.0229885  │
# ├─────────┼────────────┤
# │ age(60) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(61) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(62) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(63) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(65) │ 0.0114943  │
# ├─────────┼────────────┤
# │ age(66) │ 0          │
# ╘═════════╧════════════╛

# %%
print(model.get_cpds('chol'))
# Out:
# ╒══════════════╤══════════════════════╤══════════════════════╕
# │ heartdisease │ heartdisease(0)      │ heartdisease(1)      │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(100)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(117)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(129)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(132)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(147)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(156)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(160)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(161)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(163)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(164)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(166)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(167)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(168)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(171)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(172)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(173)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(175)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(179)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(180)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(182)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(184)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(186)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(187)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(188)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(190)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(193)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(194)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(195)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(196)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(198)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(200)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(201)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(202)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(204)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(205)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(206)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(207)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(208)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(209)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(210)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(211)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(212)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(213)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(214)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(215)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(216)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(217)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(218)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(219)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(220)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(221)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(222)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(223)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(224)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(225)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(226)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(227)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(228)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(229)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(230)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(231)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(233)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(234)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(237)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(238)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(240)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(241)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(242)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(243)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(245)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(246)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(247)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(248)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(249)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(250)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(251)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(253)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(254)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(255)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(256)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(257)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(259)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(260)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(263)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(264)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(265)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(266)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(267)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(268)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(269)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(270)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(271)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(272)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(273)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(274)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(275)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(276)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(277)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(279)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(280)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(281)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(282)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(283)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(284)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(285)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(287)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(288)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(289)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(290)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(291)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(292)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(294)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(295)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(297)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(298)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(303)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(305)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(306)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(307)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(308)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(309)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(312)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(315)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(318)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(320)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(326)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(328)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(329)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(331)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(336)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(338)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(339)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(340)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(341)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(342)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(344)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(347)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(355)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(358)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(365)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(388)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(392)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(393)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(394)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(404)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(412)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(466)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(468)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(491)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(518)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(529)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(603)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(85)     │ 0.006535947712418301 │ 0.006535947712418301 │
# ╘══════════════╧══════════════════════╧══════════════════════╛

# %%
print(model.get_cpds('sex'))
# Out:
# ╒════════╤══════════╕
# │ sex(0) │ 0.264368 │
# ├────────┼──────────┤
# │ sex(1) │ 0.735632 │
# ╘════════╧══════════╛

# %%
model.get_independencies()
# Out:
# (age _|_ sex, exang)
# (age _|_ sex, exang | fbs)
# (age _|_ restecg, thalach, chol | heartdisease)
# (age _|_ sex | exang)
# (age _|_ exang | sex)
# (age _|_ restecg, thalach, chol | fbs, heartdisease)
# (age _|_ heartdisease, restecg, thalach, chol | fbs, trestbps)
# (age _|_ sex | fbs, exang)
# (age _|_ exang | fbs, sex)
# (age _|_ restecg, chol | heartdisease, thalach)
# (age _|_ restecg, thalach | heartdisease, chol)
# (age _|_ restecg, thalach, chol | heartdisease, trestbps)
# (age _|_ restecg, thalach, chol | heartdisease, exang)
# (age _|_ thalach, chol | heartdisease, restecg)
# (age _|_ restecg, thalach, chol | heartdisease, sex)
# (age _|_ restecg, chol | fbs, heartdisease, thalach)
# (age _|_ restecg, thalach | fbs, heartdisease, chol)
# (age _|_ restecg, thalach, chol | fbs, heartdisease, trestbps)
# (age _|_ restecg, thalach, chol | fbs, heartdisease, exang)
# (age _|_ thalach, chol | fbs, heartdisease, restecg)
# (age _|_ restecg, thalach, chol | fbs, heartdisease, sex)
# (age _|_ heartdisease, restecg, chol | fbs, thalach, trestbps)
# (age _|_ heartdisease, restecg, thalach | fbs, trestbps, chol)
# (age _|_ heartdisease, restecg, thalach, chol | fbs, trestbps, exang)
# (age _|_ heartdisease, thalach, chol | fbs, restecg, trestbps)
# (age _|_ heartdisease, restecg, thalach, chol | fbs, sex, trestbps)
# (age _|_ restecg | heartdisease, thalach, chol)
# (age _|_ restecg, chol | heartdisease, thalach, trestbps)
# (age _|_ restecg, chol | heartdisease, thalach, exang)
# (age _|_ chol | heartdisease, restecg, thalach)
# (age _|_ restecg, chol | heartdisease, sex, thalach)
# (age _|_ restecg, thalach | heartdisease, trestbps, chol)
# (age _|_ restecg, thalach | heartdisease, exang, chol)
# (age _|_ thalach | heartdisease, restecg, chol)
# (age _|_ restecg, thalach | heartdisease, sex, chol)
# (age _|_ restecg, thalach, chol | heartdisease, trestbps, exang)
# (age _|_ thalach, chol | heartdisease, restecg, trestbps)
# (age _|_ restecg, thalach, chol | heartdisease, sex, trestbps)
# (age _|_ thalach, chol | heartdisease, restecg, exang)
# (age _|_ restecg, thalach, chol | heartdisease, sex, exang)
# (age _|_ thalach, chol | heartdisease, restecg, sex)
# (age _|_ restecg | fbs, heartdisease, thalach, chol)
# (age _|_ restecg, chol | fbs, heartdisease, thalach, trestbps)
# (age _|_ restecg, chol | fbs, heartdisease, thalach, exang)
# (age _|_ chol | fbs, heartdisease, restecg, thalach)
# (age _|_ restecg, chol | fbs, sex, heartdisease, thalach)
# (age _|_ restecg, thalach | fbs, heartdisease, trestbps, chol)
# (age _|_ restecg, thalach | fbs, heartdisease, exang, chol)
# (age _|_ thalach | fbs, heartdisease, restecg, chol)
# (age _|_ restecg, thalach | fbs, heartdisease, sex, chol)
# (age _|_ restecg, thalach, chol | fbs, heartdisease, trestbps, exang)
# (age _|_ thalach, chol | fbs, heartdisease, restecg, trestbps)
# (age _|_ restecg, thalach, chol | fbs, sex, heartdisease, trestbps)
# (age _|_ thalach, chol | fbs, heartdisease, restecg, exang)
# (age _|_ restecg, thalach, chol | fbs, sex, heartdisease, exang)
# (age _|_ thalach, chol | fbs, heartdisease, restecg, sex)
# (age _|_ heartdisease, restecg | fbs, thalach, trestbps, chol)
# (age _|_ heartdisease, restecg, chol | fbs, thalach, exang, trestbps)
# (age _|_ heartdisease, chol | fbs, restecg, thalach, trestbps)
# (age _|_ heartdisease, restecg, chol | fbs, sex, thalach, trestbps)
# (age _|_ heartdisease, restecg, thalach | fbs, trestbps, exang, chol)
# (age _|_ heartdisease, thalach | fbs, restecg, trestbps, chol)
# (age _|_ heartdisease, restecg, thalach | fbs, sex, trestbps, chol)
# (age _|_ heartdisease, thalach, chol | fbs, restecg, trestbps, exang)
# (age _|_ heartdisease, restecg, thalach, chol | fbs, sex, trestbps, exang)
# (age _|_ heartdisease, thalach, chol | fbs, sex, restecg, trestbps)
# (age _|_ restecg | heartdisease, thalach, trestbps, chol)
# (age _|_ restecg | heartdisease, thalach, exang, chol)
# (age _|_ restecg | heartdisease, sex, thalach, chol)
# (age _|_ restecg, chol | heartdisease, thalach, exang, trestbps)
# (age _|_ chol | heartdisease, restecg, thalach, trestbps)
# (age _|_ restecg, chol | heartdisease, sex, thalach, trestbps)
# (age _|_ chol | heartdisease, restecg, thalach, exang)
# (age _|_ restecg, chol | heartdisease, sex, thalach, exang)
# (age _|_ chol | heartdisease, sex, restecg, thalach)
# (age _|_ restecg, thalach | heartdisease, trestbps, exang, chol)
# (age _|_ thalach | heartdisease, restecg, trestbps, chol)
# (age _|_ restecg, thalach | heartdisease, sex, trestbps, chol)
# (age _|_ thalach | heartdisease, restecg, exang, chol)
# (age _|_ restecg, thalach | heartdisease, sex, exang, chol)
# (age _|_ thalach | heartdisease, restecg, sex, chol)
# (age _|_ thalach, chol | heartdisease, restecg, trestbps, exang)
# (age _|_ restecg, thalach, chol | heartdisease, sex, trestbps, exang)
# (age _|_ thalach, chol | heartdisease, sex, restecg, trestbps)
# (age _|_ thalach, chol | heartdisease, sex, restecg, exang)
# (age _|_ restecg | fbs, heartdisease, thalach, chol, trestbps)
# (age _|_ restecg | fbs, heartdisease, thalach, chol, exang)
# (age _|_ restecg | fbs, heartdisease, thalach, chol, sex)
# (age _|_ restecg, chol | fbs, heartdisease, thalach, trestbps, exang)
# (age _|_ chol | fbs, heartdisease, thalach, trestbps, restecg)
# (age _|_ restecg, chol | fbs, heartdisease, thalach, trestbps, sex)
# (age _|_ chol | fbs, heartdisease, thalach, exang, restecg)
# (age _|_ restecg, chol | fbs, heartdisease, thalach, exang, sex)
# (age _|_ chol | fbs, heartdisease, thalach, restecg, sex)
# (age _|_ restecg, thalach | fbs, heartdisease, chol, trestbps, exang)
# (age _|_ thalach | fbs, heartdisease, chol, trestbps, restecg)
# (age _|_ restecg, thalach | fbs, heartdisease, chol, trestbps, sex)
# (age _|_ thalach | fbs, heartdisease, chol, exang, restecg)
# (age _|_ restecg, thalach | fbs, heartdisease, chol, exang, sex)
# (age _|_ thalach | fbs, heartdisease, chol, restecg, sex)
# (age _|_ thalach, chol | fbs, heartdisease, trestbps, exang, restecg)
# (age _|_ restecg, thalach, chol | fbs, heartdisease, trestbps, exang, sex)
# (age _|_ thalach, chol | fbs, heartdisease, trestbps, restecg, sex)
# (age _|_ thalach, chol | fbs, heartdisease, exang, restecg, sex)
# (age _|_ heartdisease, restecg | fbs, thalach, chol, trestbps, exang)
# (age _|_ heartdisease | fbs, thalach, chol, trestbps, restecg)
# (age _|_ heartdisease, restecg | fbs, thalach, chol, trestbps, sex)
# (age _|_ heartdisease, chol | fbs, thalach, trestbps, exang, restecg)
# (age _|_ heartdisease, restecg, chol | fbs, thalach, trestbps, exang, sex)
# (age _|_ heartdisease, chol | fbs, thalach, trestbps, restecg, sex)
# (age _|_ heartdisease, thalach | fbs, chol, trestbps, exang, restecg)
# (age _|_ heartdisease, restecg, thalach | fbs, chol, trestbps, exang, sex)
# (age _|_ heartdisease, thalach | fbs, chol, trestbps, restecg, sex)
# (age _|_ heartdisease, thalach, chol | fbs, trestbps, exang, restecg, sex)
# (age _|_ restecg | heartdisease, thalach, chol, trestbps, exang)
# (age _|_ restecg | heartdisease, thalach, chol, trestbps, sex)
# (age _|_ restecg | heartdisease, thalach, chol, exang, sex)
# (age _|_ chol | heartdisease, thalach, trestbps, exang, restecg)
# (age _|_ restecg, chol | heartdisease, thalach, trestbps, exang, sex)
# (age _|_ chol | heartdisease, thalach, trestbps, restecg, sex)
# (age _|_ chol | heartdisease, thalach, exang, restecg, sex)
# (age _|_ thalach | heartdisease, chol, trestbps, exang, restecg)
# (age _|_ restecg, thalach | heartdisease, chol, trestbps, exang, sex)
# (age _|_ thalach | heartdisease, chol, trestbps, restecg, sex)
# (age _|_ thalach | heartdisease, chol, exang, restecg, sex)
# (age _|_ thalach, chol | heartdisease, trestbps, exang, restecg, sex)
# (age _|_ restecg | fbs, heartdisease, thalach, chol, trestbps, exang)
# (age _|_ restecg | fbs, heartdisease, thalach, chol, trestbps, sex)
# (age _|_ restecg | fbs, heartdisease, thalach, chol, exang, sex)
# (age _|_ chol | fbs, heartdisease, thalach, trestbps, exang, restecg)
# (age _|_ restecg, chol | fbs, heartdisease, thalach, trestbps, exang, sex)
# (age _|_ chol | fbs, heartdisease, thalach, trestbps, restecg, sex)
# (age _|_ chol | fbs, heartdisease, thalach, exang, restecg, sex)
# (age _|_ thalach | fbs, heartdisease, chol, trestbps, exang, restecg)
# (age _|_ restecg, thalach | fbs, heartdisease, chol, trestbps, exang, sex)
# (age _|_ thalach | fbs, heartdisease, chol, trestbps, restecg, sex)
# (age _|_ thalach | fbs, heartdisease, chol, exang, restecg, sex)
# (age _|_ thalach, chol | fbs, heartdisease, trestbps, exang, restecg, sex)
# (age _|_ heartdisease | fbs, thalach, chol, trestbps, exang, restecg)
# (age _|_ heartdisease, restecg | fbs, thalach, chol, trestbps, exang, sex)
# (age _|_ heartdisease | fbs, thalach, chol, trestbps, restecg, sex)
# (age _|_ heartdisease, chol | fbs, thalach, trestbps, exang, restecg, sex)
# (age _|_ heartdisease, thalach | fbs, chol, trestbps, exang, restecg, sex)
# (age _|_ restecg | heartdisease, thalach, chol, trestbps, exang, sex)
# (age _|_ chol | heartdisease, thalach, trestbps, exang, restecg, sex)
# (age _|_ thalach | heartdisease, chol, trestbps, exang, restecg, sex)
# (age _|_ restecg | fbs, heartdisease, thalach, chol, trestbps, exang, sex)
# (age _|_ chol | fbs, heartdisease, thalach, trestbps, exang, restecg, sex)
# (age _|_ thalach | fbs, heartdisease, chol, trestbps, exang, restecg, sex)
# (age _|_ heartdisease | fbs, thalach, chol, trestbps, exang, restecg, sex)
# (trestbps _|_ restecg, thalach, chol | heartdisease)
# (trestbps _|_ fbs | age)
# (trestbps _|_ restecg, thalach, chol | fbs, heartdisease)
# (trestbps _|_ restecg, chol | heartdisease, thalach)
# (trestbps _|_ restecg, thalach, chol | heartdisease, age)
# (trestbps _|_ restecg, thalach | heartdisease, chol)
# (trestbps _|_ restecg, thalach, chol | heartdisease, exang)
# (trestbps _|_ thalach, chol | heartdisease, restecg)
# (trestbps _|_ restecg, thalach, chol | heartdisease, sex)
# (trestbps _|_ fbs | exang, age)
# (trestbps _|_ fbs | sex, age)
# (trestbps _|_ restecg, chol | fbs, heartdisease, thalach)
# (trestbps _|_ restecg, thalach, chol | fbs, heartdisease, age)
# (trestbps _|_ restecg, thalach | fbs, heartdisease, chol)
# (trestbps _|_ restecg, thalach, chol | fbs, heartdisease, exang)
# (trestbps _|_ thalach, chol | fbs, heartdisease, restecg)
# (trestbps _|_ restecg, thalach, chol | fbs, heartdisease, sex)
# (trestbps _|_ restecg, chol | heartdisease, thalach, age)
# (trestbps _|_ restecg | heartdisease, thalach, chol)
# (trestbps _|_ restecg, chol | heartdisease, thalach, exang)
# (trestbps _|_ chol | heartdisease, restecg, thalach)
# (trestbps _|_ restecg, chol | heartdisease, sex, thalach)
# (trestbps _|_ restecg, thalach | heartdisease, chol, age)
# (trestbps _|_ restecg, thalach, chol | heartdisease, exang, age)
# (trestbps _|_ thalach, chol | heartdisease, restecg, age)
# (trestbps _|_ restecg, thalach, chol | heartdisease, sex, age)
# (trestbps _|_ restecg, thalach | heartdisease, exang, chol)
# (trestbps _|_ thalach | heartdisease, restecg, chol)
# (trestbps _|_ restecg, thalach | heartdisease, sex, chol)
# (trestbps _|_ thalach, chol | heartdisease, restecg, exang)
# (trestbps _|_ restecg, thalach, chol | heartdisease, sex, exang)
# (trestbps _|_ thalach, chol | heartdisease, restecg, sex)
# (trestbps _|_ fbs | sex, exang, age)
# (trestbps _|_ restecg, chol | fbs, heartdisease, thalach, age)
# (trestbps _|_ restecg | fbs, heartdisease, thalach, chol)
# (trestbps _|_ restecg, chol | fbs, heartdisease, thalach, exang)
# (trestbps _|_ chol | fbs, heartdisease, restecg, thalach)
# (trestbps _|_ restecg, chol | fbs, sex, heartdisease, thalach)
# (trestbps _|_ restecg, thalach | fbs, heartdisease, chol, age)
# (trestbps _|_ restecg, thalach, chol | fbs, heartdisease, exang, age)
# (trestbps _|_ thalach, chol | fbs, heartdisease, restecg, age)
# (trestbps _|_ restecg, thalach, chol | fbs, heartdisease, sex, age)
# (trestbps _|_ restecg, thalach | fbs, heartdisease, exang, chol)
# (trestbps _|_ thalach | fbs, heartdisease, restecg, chol)
# (trestbps _|_ restecg, thalach | fbs, heartdisease, sex, chol)
# (trestbps _|_ thalach, chol | fbs, heartdisease, restecg, exang)
# (trestbps _|_ restecg, thalach, chol | fbs, sex, heartdisease, exang)
# (trestbps _|_ thalach, chol | fbs, heartdisease, restecg, sex)
# (trestbps _|_ restecg | heartdisease, thalach, chol, age)
# (trestbps _|_ restecg, chol | heartdisease, thalach, exang, age)
# (trestbps _|_ chol | heartdisease, restecg, thalach, age)
# (trestbps _|_ restecg, chol | heartdisease, sex, thalach, age)
# (trestbps _|_ restecg | heartdisease, thalach, exang, chol)
# (trestbps _|_ restecg | heartdisease, sex, thalach, chol)
# (trestbps _|_ chol | heartdisease, restecg, thalach, exang)
# (trestbps _|_ restecg, chol | heartdisease, sex, thalach, exang)
# (trestbps _|_ chol | heartdisease, sex, restecg, thalach)
# (trestbps _|_ restecg, thalach | heartdisease, exang, chol, age)
# (trestbps _|_ thalach | heartdisease, restecg, chol, age)
# (trestbps _|_ restecg, thalach | heartdisease, sex, chol, age)
# (trestbps _|_ thalach, chol | heartdisease, restecg, exang, age)
# (trestbps _|_ restecg, thalach, chol | heartdisease, sex, exang, age)
# (trestbps _|_ thalach, chol | heartdisease, restecg, sex, age)
# (trestbps _|_ thalach | heartdisease, restecg, exang, chol)
# (trestbps _|_ restecg, thalach | heartdisease, sex, exang, chol)
# (trestbps _|_ thalach | heartdisease, restecg, sex, chol)
# (trestbps _|_ thalach, chol | heartdisease, sex, restecg, exang)
# (trestbps _|_ restecg | fbs, heartdisease, thalach, chol, age)
# (trestbps _|_ restecg, chol | fbs, heartdisease, thalach, age, exang)
# (trestbps _|_ chol | fbs, heartdisease, thalach, age, restecg)
# (trestbps _|_ restecg, chol | fbs, heartdisease, thalach, age, sex)
# (trestbps _|_ restecg | fbs, heartdisease, thalach, chol, exang)
# (trestbps _|_ restecg | fbs, heartdisease, thalach, chol, sex)
# (trestbps _|_ chol | fbs, heartdisease, thalach, exang, restecg)
# (trestbps _|_ restecg, chol | fbs, heartdisease, thalach, exang, sex)
# (trestbps _|_ chol | fbs, heartdisease, thalach, restecg, sex)
# (trestbps _|_ restecg, thalach | fbs, heartdisease, chol, age, exang)
# (trestbps _|_ thalach | fbs, heartdisease, chol, age, restecg)
# (trestbps _|_ restecg, thalach | fbs, heartdisease, chol, age, sex)
# (trestbps _|_ thalach, chol | fbs, heartdisease, age, exang, restecg)
# (trestbps _|_ restecg, thalach, chol | fbs, heartdisease, age, exang, sex)
# (trestbps _|_ thalach, chol | fbs, heartdisease, age, restecg, sex)
# (trestbps _|_ thalach | fbs, heartdisease, chol, exang, restecg)
# (trestbps _|_ restecg, thalach | fbs, heartdisease, chol, exang, sex)
# (trestbps _|_ thalach | fbs, heartdisease, chol, restecg, sex)
# (trestbps _|_ thalach, chol | fbs, heartdisease, exang, restecg, sex)
# (trestbps _|_ restecg | heartdisease, thalach, chol, age, exang)
# (trestbps _|_ restecg | heartdisease, thalach, chol, age, sex)
# (trestbps _|_ chol | heartdisease, thalach, age, exang, restecg)
# (trestbps _|_ restecg, chol | heartdisease, thalach, age, exang, sex)
# (trestbps _|_ chol | heartdisease, thalach, age, restecg, sex)
# (trestbps _|_ restecg | heartdisease, thalach, chol, exang, sex)
# (trestbps _|_ chol | heartdisease, thalach, exang, restecg, sex)
# (trestbps _|_ thalach | heartdisease, chol, age, exang, restecg)
# (trestbps _|_ restecg, thalach | heartdisease, chol, age, exang, sex)
# (trestbps _|_ thalach | heartdisease, chol, age, restecg, sex)
# (trestbps _|_ thalach, chol | heartdisease, age, exang, restecg, sex)
# (trestbps _|_ thalach | heartdisease, chol, exang, restecg, sex)
# (trestbps _|_ restecg | fbs, heartdisease, thalach, chol, age, exang)
# (trestbps _|_ restecg | fbs, heartdisease, thalach, chol, age, sex)
# (trestbps _|_ chol | fbs, heartdisease, thalach, age, exang, restecg)
# (trestbps _|_ restecg, chol | fbs, heartdisease, thalach, age, exang, sex)
# (trestbps _|_ chol | fbs, heartdisease, thalach, age, restecg, sex)
# (trestbps _|_ restecg | fbs, heartdisease, thalach, chol, exang, sex)
# (trestbps _|_ chol | fbs, heartdisease, thalach, exang, restecg, sex)
# (trestbps _|_ thalach | fbs, heartdisease, chol, age, exang, restecg)
# (trestbps _|_ restecg, thalach | fbs, heartdisease, chol, age, exang, sex)
# (trestbps _|_ thalach | fbs, heartdisease, chol, age, restecg, sex)
# (trestbps _|_ thalach, chol | fbs, heartdisease, age, exang, restecg, sex)
# (trestbps _|_ thalach | fbs, heartdisease, chol, exang, restecg, sex)
# (trestbps _|_ restecg | heartdisease, thalach, chol, age, exang, sex)
# (trestbps _|_ chol | heartdisease, thalach, age, exang, restecg, sex)
# (trestbps _|_ thalach | heartdisease, chol, age, exang, restecg, sex)
# (trestbps _|_ restecg | fbs, heartdisease, thalach, chol, age, exang, sex)
# (trestbps _|_ chol | fbs, heartdisease, thalach, age, exang, restecg, sex)
# (trestbps _|_ thalach | fbs, heartdisease, chol, age, exang, restecg, sex)
# (fbs _|_ sex, exang)
# (fbs _|_ restecg, thalach, chol | heartdisease)
# (fbs _|_ sex, trestbps, exang | age)
# (fbs _|_ sex | exang)
# (fbs _|_ exang | sex)
# (fbs _|_ restecg, chol | heartdisease, thalach)
# (fbs _|_ restecg, thalach, chol | heartdisease, age)
# (fbs _|_ restecg, thalach | heartdisease, chol)
# (fbs _|_ restecg, thalach, chol | heartdisease, trestbps)
# (fbs _|_ restecg, thalach, chol | heartdisease, exang)
# (fbs _|_ thalach, chol | heartdisease, restecg)
# (fbs _|_ restecg, thalach, chol | heartdisease, sex)
# (fbs _|_ sex, exang | trestbps, age)
# (fbs _|_ sex, trestbps | exang, age)
# (fbs _|_ trestbps, exang | sex, age)
# (fbs _|_ restecg, chol | heartdisease, thalach, age)
# (fbs _|_ restecg | heartdisease, thalach, chol)
# (fbs _|_ restecg, chol | heartdisease, thalach, trestbps)
# (fbs _|_ restecg, chol | heartdisease, thalach, exang)
# (fbs _|_ chol | heartdisease, restecg, thalach)
# (fbs _|_ restecg, chol | heartdisease, sex, thalach)
# (fbs _|_ restecg, thalach | heartdisease, chol, age)
# (fbs _|_ thalach, exang, chol, restecg, sex | heartdisease, trestbps, age)
# (fbs _|_ restecg, thalach, chol | heartdisease, exang, age)
# (fbs _|_ thalach, chol | heartdisease, restecg, age)
# (fbs _|_ restecg, thalach, chol | heartdisease, sex, age)
# (fbs _|_ restecg, thalach | heartdisease, trestbps, chol)
# (fbs _|_ restecg, thalach | heartdisease, exang, chol)
# (fbs _|_ thalach | heartdisease, restecg, chol)
# (fbs _|_ restecg, thalach | heartdisease, sex, chol)
# (fbs _|_ restecg, thalach, chol | heartdisease, trestbps, exang)
# (fbs _|_ thalach, chol | heartdisease, restecg, trestbps)
# (fbs _|_ restecg, thalach, chol | heartdisease, sex, trestbps)
# (fbs _|_ thalach, chol | heartdisease, restecg, exang)
# (fbs _|_ restecg, thalach, chol | heartdisease, sex, exang)
# (fbs _|_ thalach, chol | heartdisease, restecg, sex)
# (fbs _|_ sex, exang | trestbps, thalach, age)
# (fbs _|_ sex, exang | trestbps, chol, age)
# (fbs _|_ sex | trestbps, exang, age)
# (fbs _|_ sex, exang | restecg, trestbps, age)
# (fbs _|_ exang | sex, trestbps, age)
# (fbs _|_ trestbps | sex, exang, age)
# (fbs _|_ restecg | heartdisease, thalach, chol, age)
# (fbs _|_ restecg, sex, exang, chol | heartdisease, thalach, trestbps, age)
# (fbs _|_ restecg, chol | heartdisease, thalach, exang, age)
# (fbs _|_ chol | heartdisease, restecg, thalach, age)
# (fbs _|_ restecg, chol | heartdisease, sex, thalach, age)
# (fbs _|_ restecg | heartdisease, thalach, trestbps, chol)
# (fbs _|_ restecg | heartdisease, thalach, exang, chol)
# (fbs _|_ restecg | heartdisease, sex, thalach, chol)
# (fbs _|_ restecg, chol | heartdisease, thalach, exang, trestbps)
# (fbs _|_ chol | heartdisease, restecg, thalach, trestbps)
# (fbs _|_ restecg, chol | heartdisease, sex, thalach, trestbps)
# (fbs _|_ chol | heartdisease, restecg, thalach, exang)
# (fbs _|_ restecg, chol | heartdisease, sex, thalach, exang)
# (fbs _|_ chol | heartdisease, sex, restecg, thalach)
# (fbs _|_ restecg, exang, sex, thalach | heartdisease, trestbps, chol, age)
# (fbs _|_ restecg, thalach | heartdisease, exang, chol, age)
# (fbs _|_ thalach | heartdisease, restecg, chol, age)
# (fbs _|_ restecg, thalach | heartdisease, sex, chol, age)
# (fbs _|_ restecg, sex, thalach, chol | heartdisease, trestbps, exang, age)
# (fbs _|_ thalach, sex, exang, chol | heartdisease, restecg, trestbps, age)
# (fbs _|_ restecg, thalach, exang, chol | heartdisease, sex, trestbps, age)
# (fbs _|_ thalach, chol | heartdisease, restecg, exang, age)
# (fbs _|_ restecg, thalach, chol | heartdisease, sex, exang, age)
# (fbs _|_ thalach, chol | heartdisease, restecg, sex, age)
# (fbs _|_ restecg, thalach | heartdisease, trestbps, exang, chol)
# (fbs _|_ thalach | heartdisease, restecg, trestbps, chol)
# (fbs _|_ restecg, thalach | heartdisease, sex, trestbps, chol)
# (fbs _|_ thalach | heartdisease, restecg, exang, chol)
# (fbs _|_ restecg, thalach | heartdisease, sex, exang, chol)
# (fbs _|_ thalach | heartdisease, restecg, sex, chol)
# (fbs _|_ thalach, chol | heartdisease, restecg, trestbps, exang)
# (fbs _|_ restecg, thalach, chol | heartdisease, sex, trestbps, exang)
# (fbs _|_ thalach, chol | heartdisease, sex, restecg, trestbps)
# (fbs _|_ thalach, chol | heartdisease, sex, restecg, exang)
# (fbs _|_ sex, exang | trestbps, thalach, chol, age)
# (fbs _|_ sex | trestbps, thalach, exang, age)
# (fbs _|_ sex, exang | trestbps, restecg, thalach, age)
# (fbs _|_ exang | trestbps, sex, thalach, age)
# (fbs _|_ sex | exang, trestbps, chol, age)
# (fbs _|_ sex, exang | restecg, trestbps, chol, age)
# (fbs _|_ exang | sex, trestbps, chol, age)
# (fbs _|_ sex | restecg, trestbps, exang, age)
# (fbs _|_ exang | sex, restecg, trestbps, age)
# (fbs _|_ restecg, sex, exang | heartdisease, thalach, chol, age, trestbps)
# (fbs _|_ restecg | heartdisease, thalach, chol, age, exang)
# (fbs _|_ restecg | heartdisease, thalach, chol, age, sex)
# (fbs _|_ restecg, sex, chol | heartdisease, thalach, age, trestbps, exang)
# (fbs _|_ sex, exang, chol | heartdisease, thalach, age, trestbps, restecg)
# (fbs _|_ restecg, exang, chol | heartdisease, thalach, age, trestbps, sex)
# (fbs _|_ chol | heartdisease, thalach, age, exang, restecg)
# (fbs _|_ restecg, chol | heartdisease, thalach, age, exang, sex)
# (fbs _|_ chol | heartdisease, thalach, age, restecg, sex)
# (fbs _|_ restecg | heartdisease, thalach, chol, trestbps, exang)
# (fbs _|_ restecg | heartdisease, thalach, chol, trestbps, sex)
# (fbs _|_ restecg | heartdisease, thalach, chol, exang, sex)
# (fbs _|_ chol | heartdisease, thalach, trestbps, exang, restecg)
# (fbs _|_ restecg, chol | heartdisease, thalach, trestbps, exang, sex)
# (fbs _|_ chol | heartdisease, thalach, trestbps, restecg, sex)
# (fbs _|_ chol | heartdisease, thalach, exang, restecg, sex)
# (fbs _|_ restecg, sex, thalach | heartdisease, chol, age, trestbps, exang)
# (fbs _|_ thalach, sex, exang | heartdisease, chol, age, trestbps, restecg)
# (fbs _|_ restecg, thalach, exang | heartdisease, chol, age, trestbps, sex)
# (fbs _|_ thalach | heartdisease, chol, age, exang, restecg)
# (fbs _|_ restecg, thalach | heartdisease, chol, age, exang, sex)
# (fbs _|_ thalach | heartdisease, chol, age, restecg, sex)
# (fbs _|_ thalach, sex, chol | heartdisease, age, trestbps, exang, restecg)
# (fbs _|_ restecg, thalach, chol | heartdisease, age, trestbps, exang, sex)
# (fbs _|_ thalach, exang, chol | heartdisease, age, trestbps, restecg, sex)
# (fbs _|_ thalach, chol | heartdisease, age, exang, restecg, sex)
# (fbs _|_ thalach | heartdisease, chol, trestbps, exang, restecg)
# (fbs _|_ restecg, thalach | heartdisease, chol, trestbps, exang, sex)
# (fbs _|_ thalach | heartdisease, chol, trestbps, restecg, sex)
# (fbs _|_ thalach | heartdisease, chol, exang, restecg, sex)
# (fbs _|_ thalach, chol | heartdisease, trestbps, exang, restecg, sex)
# (fbs _|_ sex | thalach, chol, age, trestbps, exang)
# (fbs _|_ sex, exang | thalach, chol, age, trestbps, restecg)
# (fbs _|_ exang | thalach, chol, age, trestbps, sex)
# (fbs _|_ sex | thalach, age, trestbps, exang, restecg)
# (fbs _|_ exang | thalach, age, trestbps, restecg, sex)
# (fbs _|_ sex | chol, age, trestbps, exang, restecg)
# (fbs _|_ exang | chol, age, trestbps, restecg, sex)
# (fbs _|_ restecg, sex | heartdisease, thalach, chol, age, trestbps, exang)
# (fbs _|_ sex, exang | heartdisease, thalach, chol, age, trestbps, restecg)
# (fbs _|_ restecg, exang | heartdisease, thalach, chol, age, trestbps, sex)
# (fbs _|_ restecg | heartdisease, thalach, chol, age, exang, sex)
# (fbs _|_ sex, chol | heartdisease, thalach, age, trestbps, exang, restecg)
# (fbs _|_ restecg, chol | heartdisease, thalach, age, trestbps, exang, sex)
# (fbs _|_ exang, chol | heartdisease, thalach, age, trestbps, restecg, sex)
# (fbs _|_ chol | heartdisease, thalach, age, exang, restecg, sex)
# (fbs _|_ restecg | heartdisease, thalach, chol, trestbps, exang, sex)
# (fbs _|_ chol | heartdisease, thalach, trestbps, exang, restecg, sex)
# (fbs _|_ thalach, sex | heartdisease, chol, age, trestbps, exang, restecg)
# (fbs _|_ restecg, thalach | heartdisease, chol, age, trestbps, exang, sex)
# (fbs _|_ thalach, exang | heartdisease, chol, age, trestbps, restecg, sex)
# (fbs _|_ thalach | heartdisease, chol, age, exang, restecg, sex)
# (fbs _|_ thalach, chol | heartdisease, age, trestbps, exang, restecg, sex)
# (fbs _|_ thalach | heartdisease, chol, trestbps, exang, restecg, sex)
# (fbs _|_ sex | thalach, chol, age, trestbps, exang, restecg)
# (fbs _|_ exang | thalach, chol, age, trestbps, restecg, sex)
# (fbs _|_ sex | heartdisease, thalach, chol, age, trestbps, exang, restecg)
# (fbs _|_ restecg | heartdisease, thalach, chol, age, trestbps, exang, sex)
# (fbs _|_ exang | heartdisease, thalach, chol, age, trestbps, restecg, sex)
# (fbs _|_ chol | heartdisease, thalach, age, trestbps, exang, restecg, sex)
# (fbs _|_ thalach | heartdisease, chol, age, trestbps, exang, restecg, sex)
# (sex _|_ fbs, exang, age)
# (sex _|_ exang, age | fbs)
# (sex _|_ restecg, thalach, chol | heartdisease)
# (sex _|_ fbs, exang | age)
# (sex _|_ fbs, age | exang)
# (sex _|_ restecg, thalach, chol | fbs, heartdisease)
# (sex _|_ exang | fbs, age)
# (sex _|_ heartdisease, restecg, thalach, chol | fbs, trestbps)
# (sex _|_ age | fbs, exang)
# (sex _|_ restecg, chol | heartdisease, thalach)
# (sex _|_ restecg, thalach, chol | heartdisease, age)
# (sex _|_ restecg, thalach | heartdisease, chol)
# (sex _|_ restecg, thalach, chol | heartdisease, trestbps)
# (sex _|_ restecg, thalach, chol | heartdisease, exang)
# (sex _|_ thalach, chol | heartdisease, restecg)
# (sex _|_ fbs, heartdisease, thalach, chol, restecg | trestbps, age)
# (sex _|_ fbs | exang, age)
# (sex _|_ restecg, chol | fbs, heartdisease, thalach)
# (sex _|_ restecg, thalach, chol | fbs, heartdisease, age)
# (sex _|_ restecg, thalach | fbs, heartdisease, chol)
# (sex _|_ restecg, thalach, chol | fbs, heartdisease, trestbps)
# (sex _|_ restecg, thalach, chol | fbs, heartdisease, exang)
# (sex _|_ thalach, chol | fbs, heartdisease, restecg)
# (sex _|_ heartdisease, restecg, chol | fbs, thalach, trestbps)
# (sex _|_ heartdisease, restecg, thalach, chol | fbs, trestbps, age)
# (sex _|_ heartdisease, restecg, thalach | fbs, trestbps, chol)
# (sex _|_ heartdisease, restecg, thalach, chol | fbs, trestbps, exang)
# (sex _|_ heartdisease, thalach, chol | fbs, restecg, trestbps)
# (sex _|_ restecg, chol | heartdisease, thalach, age)
# (sex _|_ restecg | heartdisease, thalach, chol)
# (sex _|_ restecg, chol | heartdisease, thalach, trestbps)
# (sex _|_ restecg, chol | heartdisease, thalach, exang)
# (sex _|_ chol | heartdisease, restecg, thalach)
# (sex _|_ restecg, thalach | heartdisease, chol, age)
# (sex _|_ fbs, restecg, thalach, chol | heartdisease, trestbps, age)
# (sex _|_ restecg, thalach, chol | heartdisease, exang, age)
# (sex _|_ thalach, chol | heartdisease, restecg, age)
# (sex _|_ restecg, thalach | heartdisease, trestbps, chol)
# (sex _|_ restecg, thalach | heartdisease, exang, chol)
# (sex _|_ thalach | heartdisease, restecg, chol)
# (sex _|_ restecg, thalach, chol | heartdisease, trestbps, exang)
# (sex _|_ thalach, chol | heartdisease, restecg, trestbps)
# (sex _|_ thalach, chol | heartdisease, restecg, exang)
# (sex _|_ fbs, heartdisease, restecg, chol | trestbps, thalach, age)
# (sex _|_ fbs, heartdisease, restecg, thalach | trestbps, chol, age)
# (sex _|_ fbs, heartdisease, thalach, chol, restecg | trestbps, exang, age)
# (sex _|_ fbs, heartdisease, thalach, chol | restecg, trestbps, age)
# (sex _|_ restecg, chol | fbs, heartdisease, thalach, age)
# (sex _|_ restecg | fbs, heartdisease, thalach, chol)
# (sex _|_ restecg, chol | fbs, heartdisease, thalach, trestbps)
# (sex _|_ restecg, chol | fbs, heartdisease, thalach, exang)
# (sex _|_ chol | fbs, heartdisease, restecg, thalach)
# (sex _|_ restecg, thalach | fbs, heartdisease, chol, age)
# (sex _|_ restecg, thalach, chol | fbs, heartdisease, trestbps, age)
# (sex _|_ restecg, thalach, chol | fbs, heartdisease, exang, age)
# (sex _|_ thalach, chol | fbs, heartdisease, restecg, age)
# (sex _|_ restecg, thalach | fbs, heartdisease, trestbps, chol)
# (sex _|_ restecg, thalach | fbs, heartdisease, exang, chol)
# (sex _|_ thalach | fbs, heartdisease, restecg, chol)
# (sex _|_ restecg, thalach, chol | fbs, heartdisease, trestbps, exang)
# (sex _|_ thalach, chol | fbs, heartdisease, restecg, trestbps)
# (sex _|_ thalach, chol | fbs, heartdisease, restecg, exang)
# (sex _|_ heartdisease, restecg, chol | fbs, thalach, trestbps, age)
# (sex _|_ heartdisease, restecg | fbs, thalach, trestbps, chol)
# (sex _|_ heartdisease, restecg, chol | fbs, thalach, exang, trestbps)
# (sex _|_ heartdisease, chol | fbs, restecg, thalach, trestbps)
# (sex _|_ heartdisease, restecg, thalach | fbs, trestbps, chol, age)
# (sex _|_ heartdisease, restecg, thalach, chol | fbs, trestbps, exang, age)
# (sex _|_ heartdisease, thalach, chol | fbs, restecg, trestbps, age)
# (sex _|_ heartdisease, restecg, thalach | fbs, trestbps, exang, chol)
# (sex _|_ heartdisease, thalach | fbs, restecg, trestbps, chol)
# (sex _|_ heartdisease, thalach, chol | fbs, restecg, trestbps, exang)
# (sex _|_ restecg | heartdisease, thalach, chol, age)
# (sex _|_ fbs, restecg, chol | heartdisease, thalach, trestbps, age)
# (sex _|_ restecg, chol | heartdisease, thalach, exang, age)
# (sex _|_ chol | heartdisease, restecg, thalach, age)
# (sex _|_ restecg | heartdisease, thalach, trestbps, chol)
# (sex _|_ restecg | heartdisease, thalach, exang, chol)
# (sex _|_ restecg, chol | heartdisease, thalach, exang, trestbps)
# (sex _|_ chol | heartdisease, restecg, thalach, trestbps)
# (sex _|_ chol | heartdisease, restecg, thalach, exang)
# (sex _|_ fbs, restecg, thalach | heartdisease, trestbps, chol, age)
# (sex _|_ restecg, thalach | heartdisease, exang, chol, age)
# (sex _|_ thalach | heartdisease, restecg, chol, age)
# (sex _|_ fbs, restecg, thalach, chol | heartdisease, trestbps, exang, age)
# (sex _|_ fbs, thalach, chol | heartdisease, restecg, trestbps, age)
# (sex _|_ thalach, chol | heartdisease, restecg, exang, age)
# (sex _|_ restecg, thalach | heartdisease, trestbps, exang, chol)
# (sex _|_ thalach | heartdisease, restecg, trestbps, chol)
# (sex _|_ thalach | heartdisease, restecg, exang, chol)
# (sex _|_ thalach, chol | heartdisease, restecg, trestbps, exang)
# (sex _|_ fbs, heartdisease, restecg | trestbps, thalach, chol, age)
# (sex _|_ fbs, heartdisease, restecg, chol | trestbps, thalach, exang, age)
# (sex _|_ fbs, heartdisease, chol | trestbps, restecg, thalach, age)
# (sex _|_ fbs, heartdisease, restecg, thalach | exang, trestbps, chol, age)
# (sex _|_ fbs, heartdisease, thalach | restecg, trestbps, chol, age)
# (sex _|_ fbs, heartdisease, thalach, chol | restecg, trestbps, exang, age)
# (sex _|_ restecg | fbs, heartdisease, thalach, chol, age)
# (sex _|_ restecg, chol | fbs, heartdisease, thalach, age, trestbps)
# (sex _|_ restecg, chol | fbs, heartdisease, thalach, age, exang)
# (sex _|_ chol | fbs, heartdisease, thalach, age, restecg)
# (sex _|_ restecg | fbs, heartdisease, thalach, chol, trestbps)
# (sex _|_ restecg | fbs, heartdisease, thalach, chol, exang)
# (sex _|_ restecg, chol | fbs, heartdisease, thalach, trestbps, exang)
# (sex _|_ chol | fbs, heartdisease, thalach, trestbps, restecg)
# (sex _|_ chol | fbs, heartdisease, thalach, exang, restecg)
# (sex _|_ restecg, thalach | fbs, heartdisease, chol, age, trestbps)
# (sex _|_ restecg, thalach | fbs, heartdisease, chol, age, exang)
# (sex _|_ thalach | fbs, heartdisease, chol, age, restecg)
# (sex _|_ restecg, thalach, chol | fbs, heartdisease, age, trestbps, exang)
# (sex _|_ thalach, chol | fbs, heartdisease, age, trestbps, restecg)
# (sex _|_ thalach, chol | fbs, heartdisease, age, exang, restecg)
# (sex _|_ restecg, thalach | fbs, heartdisease, chol, trestbps, exang)
# (sex _|_ thalach | fbs, heartdisease, chol, trestbps, restecg)
# (sex _|_ thalach | fbs, heartdisease, chol, exang, restecg)
# (sex _|_ thalach, chol | fbs, heartdisease, trestbps, exang, restecg)
# (sex _|_ heartdisease, restecg | fbs, thalach, chol, age, trestbps)
# (sex _|_ heartdisease, restecg, chol | fbs, thalach, age, trestbps, exang)
# (sex _|_ heartdisease, chol | fbs, thalach, age, trestbps, restecg)
# (sex _|_ heartdisease, restecg | fbs, thalach, chol, trestbps, exang)
# (sex _|_ heartdisease | fbs, thalach, chol, trestbps, restecg)
# (sex _|_ heartdisease, chol | fbs, thalach, trestbps, exang, restecg)
# (sex _|_ heartdisease, restecg, thalach | fbs, chol, age, trestbps, exang)
# (sex _|_ heartdisease, thalach | fbs, chol, age, trestbps, restecg)
# (sex _|_ heartdisease, thalach, chol | fbs, age, trestbps, exang, restecg)
# (sex _|_ heartdisease, thalach | fbs, chol, trestbps, exang, restecg)
# (sex _|_ fbs, restecg | heartdisease, thalach, chol, age, trestbps)
# (sex _|_ restecg | heartdisease, thalach, chol, age, exang)
# (sex _|_ fbs, restecg, chol | heartdisease, thalach, age, trestbps, exang)
# (sex _|_ fbs, chol | heartdisease, thalach, age, trestbps, restecg)
# (sex _|_ chol | heartdisease, thalach, age, exang, restecg)
# (sex _|_ restecg | heartdisease, thalach, chol, trestbps, exang)
# (sex _|_ chol | heartdisease, thalach, trestbps, exang, restecg)
# (sex _|_ fbs, restecg, thalach | heartdisease, chol, age, trestbps, exang)
# (sex _|_ fbs, thalach | heartdisease, chol, age, trestbps, restecg)
# (sex _|_ thalach | heartdisease, chol, age, exang, restecg)
# (sex _|_ fbs, thalach, chol | heartdisease, age, trestbps, exang, restecg)
# (sex _|_ thalach | heartdisease, chol, trestbps, exang, restecg)
# (sex _|_ fbs, heartdisease, restecg | thalach, chol, age, trestbps, exang)
# (sex _|_ fbs, heartdisease | thalach, chol, age, trestbps, restecg)
# (sex _|_ fbs, heartdisease, chol | thalach, age, trestbps, exang, restecg)
# (sex _|_ fbs, heartdisease, thalach | chol, age, trestbps, exang, restecg)
# (sex _|_ restecg | fbs, heartdisease, thalach, chol, age, trestbps)
# (sex _|_ restecg | fbs, heartdisease, thalach, chol, age, exang)
# (sex _|_ restecg, chol | fbs, heartdisease, thalach, age, trestbps, exang)
# (sex _|_ chol | fbs, heartdisease, thalach, age, trestbps, restecg)
# (sex _|_ chol | fbs, heartdisease, thalach, age, exang, restecg)
# (sex _|_ restecg | fbs, heartdisease, thalach, chol, trestbps, exang)
# (sex _|_ chol | fbs, heartdisease, thalach, trestbps, exang, restecg)
# (sex _|_ restecg, thalach | fbs, heartdisease, chol, age, trestbps, exang)
# (sex _|_ thalach | fbs, heartdisease, chol, age, trestbps, restecg)
# (sex _|_ thalach | fbs, heartdisease, chol, age, exang, restecg)
# (sex _|_ thalach, chol | fbs, heartdisease, age, trestbps, exang, restecg)
# (sex _|_ thalach | fbs, heartdisease, chol, trestbps, exang, restecg)
# (sex _|_ heartdisease, restecg | fbs, thalach, chol, age, trestbps, exang)
# (sex _|_ heartdisease | fbs, thalach, chol, age, trestbps, restecg)
# (sex _|_ heartdisease, chol | fbs, thalach, age, trestbps, exang, restecg)
# (sex _|_ heartdisease | fbs, thalach, chol, trestbps, exang, restecg)
# (sex _|_ heartdisease, thalach | fbs, chol, age, trestbps, exang, restecg)
# (sex _|_ fbs, restecg | heartdisease, thalach, chol, age, trestbps, exang)
# (sex _|_ fbs | heartdisease, thalach, chol, age, trestbps, restecg)
# (sex _|_ fbs, chol | heartdisease, thalach, age, trestbps, exang, restecg)
# (sex _|_ fbs, thalach | heartdisease, chol, age, trestbps, exang, restecg)
# (sex _|_ fbs, heartdisease | thalach, chol, age, trestbps, exang, restecg)
# (sex _|_ restecg | fbs, heartdisease, thalach, chol, age, trestbps, exang)
# (sex _|_ chol | fbs, heartdisease, thalach, age, trestbps, exang, restecg)
# (sex _|_ thalach | fbs, heartdisease, chol, age, trestbps, exang, restecg)
# (sex _|_ heartdisease | fbs, thalach, chol, age, trestbps, exang, restecg)
# (sex _|_ fbs | heartdisease, thalach, chol, age, trestbps, exang, restecg)
# (exang _|_ fbs, sex, age)
# (exang _|_ sex, age | fbs)
# (exang _|_ restecg, thalach, chol | heartdisease)
# (exang _|_ fbs, sex | age)
# (exang _|_ fbs, age | sex)
# (exang _|_ restecg, thalach, chol | fbs, heartdisease)
# (exang _|_ sex | fbs, age)
# (exang _|_ heartdisease, restecg, thalach, chol | fbs, trestbps)
# (exang _|_ age | fbs, sex)
# (exang _|_ restecg, chol | heartdisease, thalach)
# (exang _|_ restecg, thalach, chol | heartdisease, age)
# (exang _|_ restecg, thalach | heartdisease, chol)
# (exang _|_ restecg, thalach, chol | heartdisease, trestbps)
# (exang _|_ thalach, chol | heartdisease, restecg)
# (exang _|_ restecg, thalach, chol | heartdisease, sex)
# (exang _|_ fbs, heartdisease, thalach, chol, restecg | trestbps, age)
# (exang _|_ fbs | sex, age)
# (exang _|_ restecg, chol | fbs, heartdisease, thalach)
# (exang _|_ restecg, thalach, chol | fbs, heartdisease, age)
# (exang _|_ restecg, thalach | fbs, heartdisease, chol)
# (exang _|_ restecg, thalach, chol | fbs, heartdisease, trestbps)
# (exang _|_ thalach, chol | fbs, heartdisease, restecg)
# (exang _|_ restecg, thalach, chol | fbs, heartdisease, sex)
# (exang _|_ heartdisease, restecg, chol | fbs, thalach, trestbps)
# (exang _|_ heartdisease, restecg, thalach, chol | fbs, trestbps, age)
# (exang _|_ heartdisease, restecg, thalach | fbs, trestbps, chol)
# (exang _|_ heartdisease, thalach, chol | fbs, restecg, trestbps)
# (exang _|_ heartdisease, restecg, thalach, chol | fbs, sex, trestbps)
# (exang _|_ restecg, chol | heartdisease, thalach, age)
# (exang _|_ restecg | heartdisease, thalach, chol)
# (exang _|_ restecg, chol | heartdisease, thalach, trestbps)
# (exang _|_ chol | heartdisease, restecg, thalach)
# (exang _|_ restecg, chol | heartdisease, sex, thalach)
# (exang _|_ restecg, thalach | heartdisease, chol, age)
# (exang _|_ fbs, restecg, thalach, chol | heartdisease, trestbps, age)
# (exang _|_ thalach, chol | heartdisease, restecg, age)
# (exang _|_ restecg, thalach, chol | heartdisease, sex, age)
# (exang _|_ restecg, thalach | heartdisease, trestbps, chol)
# (exang _|_ thalach | heartdisease, restecg, chol)
# (exang _|_ restecg, thalach | heartdisease, sex, chol)
# (exang _|_ thalach, chol | heartdisease, restecg, trestbps)
# (exang _|_ restecg, thalach, chol | heartdisease, sex, trestbps)
# (exang _|_ thalach, chol | heartdisease, restecg, sex)
# (exang _|_ fbs, heartdisease, restecg, chol | trestbps, thalach, age)
# (exang _|_ fbs, heartdisease, restecg, thalach | trestbps, chol, age)
# (exang _|_ fbs, heartdisease, thalach, chol | restecg, trestbps, age)
# (exang _|_ fbs, heartdisease, thalach, chol, restecg | sex, trestbps, age)
# (exang _|_ restecg, chol | fbs, heartdisease, thalach, age)
# (exang _|_ restecg | fbs, heartdisease, thalach, chol)
# (exang _|_ restecg, chol | fbs, heartdisease, thalach, trestbps)
# (exang _|_ chol | fbs, heartdisease, restecg, thalach)
# (exang _|_ restecg, chol | fbs, sex, heartdisease, thalach)
# (exang _|_ restecg, thalach | fbs, heartdisease, chol, age)
# (exang _|_ restecg, thalach, chol | fbs, heartdisease, trestbps, age)
# (exang _|_ thalach, chol | fbs, heartdisease, restecg, age)
# (exang _|_ restecg, thalach, chol | fbs, heartdisease, sex, age)
# (exang _|_ restecg, thalach | fbs, heartdisease, trestbps, chol)
# (exang _|_ thalach | fbs, heartdisease, restecg, chol)
# (exang _|_ restecg, thalach | fbs, heartdisease, sex, chol)
# (exang _|_ thalach, chol | fbs, heartdisease, restecg, trestbps)
# (exang _|_ restecg, thalach, chol | fbs, sex, heartdisease, trestbps)
# (exang _|_ thalach, chol | fbs, heartdisease, restecg, sex)
# (exang _|_ heartdisease, restecg, chol | fbs, thalach, trestbps, age)
# (exang _|_ heartdisease, restecg | fbs, thalach, trestbps, chol)
# (exang _|_ heartdisease, chol | fbs, restecg, thalach, trestbps)
# (exang _|_ heartdisease, restecg, chol | fbs, sex, thalach, trestbps)
# (exang _|_ heartdisease, restecg, thalach | fbs, trestbps, chol, age)
# (exang _|_ heartdisease, thalach, chol | fbs, restecg, trestbps, age)
# (exang _|_ heartdisease, restecg, thalach, chol | fbs, sex, trestbps, age)
# (exang _|_ heartdisease, thalach | fbs, restecg, trestbps, chol)
# (exang _|_ heartdisease, restecg, thalach | fbs, sex, trestbps, chol)
# (exang _|_ heartdisease, thalach, chol | fbs, sex, restecg, trestbps)
# (exang _|_ restecg | heartdisease, thalach, chol, age)
# (exang _|_ fbs, restecg, chol | heartdisease, thalach, trestbps, age)
# (exang _|_ chol | heartdisease, restecg, thalach, age)
# (exang _|_ restecg, chol | heartdisease, sex, thalach, age)
# (exang _|_ restecg | heartdisease, thalach, trestbps, chol)
# (exang _|_ restecg | heartdisease, sex, thalach, chol)
# (exang _|_ chol | heartdisease, restecg, thalach, trestbps)
# (exang _|_ restecg, chol | heartdisease, sex, thalach, trestbps)
# (exang _|_ chol | heartdisease, sex, restecg, thalach)
# (exang _|_ fbs, restecg, thalach | heartdisease, trestbps, chol, age)
# (exang _|_ thalach | heartdisease, restecg, chol, age)
# (exang _|_ restecg, thalach | heartdisease, sex, chol, age)
# (exang _|_ fbs, thalach, chol | heartdisease, restecg, trestbps, age)
# (exang _|_ fbs, restecg, thalach, chol | heartdisease, sex, trestbps, age)
# (exang _|_ thalach, chol | heartdisease, restecg, sex, age)
# (exang _|_ thalach | heartdisease, restecg, trestbps, chol)
# (exang _|_ restecg, thalach | heartdisease, sex, trestbps, chol)
# (exang _|_ thalach | heartdisease, restecg, sex, chol)
# (exang _|_ thalach, chol | heartdisease, sex, restecg, trestbps)
# (exang _|_ fbs, heartdisease, restecg | trestbps, thalach, chol, age)
# (exang _|_ fbs, heartdisease, chol | trestbps, restecg, thalach, age)
# (exang _|_ fbs, heartdisease, restecg, chol | trestbps, sex, thalach, age)
# (exang _|_ fbs, heartdisease, thalach | restecg, trestbps, chol, age)
# (exang _|_ fbs, heartdisease, restecg, thalach | sex, trestbps, chol, age)
# (exang _|_ fbs, heartdisease, thalach, chol | sex, restecg, trestbps, age)
# (exang _|_ restecg | fbs, heartdisease, thalach, chol, age)
# (exang _|_ restecg, chol | fbs, heartdisease, thalach, age, trestbps)
# (exang _|_ chol | fbs, heartdisease, thalach, age, restecg)
# (exang _|_ restecg, chol | fbs, heartdisease, thalach, age, sex)
# (exang _|_ restecg | fbs, heartdisease, thalach, chol, trestbps)
# (exang _|_ restecg | fbs, heartdisease, thalach, chol, sex)
# (exang _|_ chol | fbs, heartdisease, thalach, trestbps, restecg)
# (exang _|_ restecg, chol | fbs, heartdisease, thalach, trestbps, sex)
# (exang _|_ chol | fbs, heartdisease, thalach, restecg, sex)
# (exang _|_ restecg, thalach | fbs, heartdisease, chol, age, trestbps)
# (exang _|_ thalach | fbs, heartdisease, chol, age, restecg)
# (exang _|_ restecg, thalach | fbs, heartdisease, chol, age, sex)
# (exang _|_ thalach, chol | fbs, heartdisease, age, trestbps, restecg)
# (exang _|_ restecg, thalach, chol | fbs, heartdisease, age, trestbps, sex)
# (exang _|_ thalach, chol | fbs, heartdisease, age, restecg, sex)
# (exang _|_ thalach | fbs, heartdisease, chol, trestbps, restecg)
# (exang _|_ restecg, thalach | fbs, heartdisease, chol, trestbps, sex)
# (exang _|_ thalach | fbs, heartdisease, chol, restecg, sex)
# (exang _|_ thalach, chol | fbs, heartdisease, trestbps, restecg, sex)
# (exang _|_ heartdisease, restecg | fbs, thalach, chol, age, trestbps)
# (exang _|_ heartdisease, chol | fbs, thalach, age, trestbps, restecg)
# (exang _|_ heartdisease, restecg, chol | fbs, thalach, age, trestbps, sex)
# (exang _|_ heartdisease | fbs, thalach, chol, trestbps, restecg)
# (exang _|_ heartdisease, restecg | fbs, thalach, chol, trestbps, sex)
# (exang _|_ heartdisease, chol | fbs, thalach, trestbps, restecg, sex)
# (exang _|_ heartdisease, thalach | fbs, chol, age, trestbps, restecg)
# (exang _|_ heartdisease, restecg, thalach | fbs, chol, age, trestbps, sex)
# (exang _|_ heartdisease, thalach, chol | fbs, age, trestbps, restecg, sex)
# (exang _|_ heartdisease, thalach | fbs, chol, trestbps, restecg, sex)
# (exang _|_ fbs, restecg | heartdisease, thalach, chol, age, trestbps)
# (exang _|_ restecg | heartdisease, thalach, chol, age, sex)
# (exang _|_ fbs, chol | heartdisease, thalach, age, trestbps, restecg)
# (exang _|_ fbs, restecg, chol | heartdisease, thalach, age, trestbps, sex)
# (exang _|_ chol | heartdisease, thalach, age, restecg, sex)
# (exang _|_ restecg | heartdisease, thalach, chol, trestbps, sex)
# (exang _|_ chol | heartdisease, thalach, trestbps, restecg, sex)
# (exang _|_ fbs, thalach | heartdisease, chol, age, trestbps, restecg)
# (exang _|_ fbs, restecg, thalach | heartdisease, chol, age, trestbps, sex)
# (exang _|_ thalach | heartdisease, chol, age, restecg, sex)
# (exang _|_ fbs, thalach, chol | heartdisease, age, trestbps, restecg, sex)
# (exang _|_ thalach | heartdisease, chol, trestbps, restecg, sex)
# (exang _|_ fbs, heartdisease | thalach, chol, age, trestbps, restecg)
# (exang _|_ fbs, heartdisease, restecg | thalach, chol, age, trestbps, sex)
# (exang _|_ fbs, heartdisease, chol | thalach, age, trestbps, restecg, sex)
# (exang _|_ fbs, heartdisease, thalach | chol, age, trestbps, restecg, sex)
# (exang _|_ restecg | fbs, heartdisease, thalach, chol, age, trestbps)
# (exang _|_ restecg | fbs, heartdisease, thalach, chol, age, sex)
# (exang _|_ chol | fbs, heartdisease, thalach, age, trestbps, restecg)
# (exang _|_ restecg, chol | fbs, heartdisease, thalach, age, trestbps, sex)
# (exang _|_ chol | fbs, heartdisease, thalach, age, restecg, sex)
# (exang _|_ restecg | fbs, heartdisease, thalach, chol, trestbps, sex)
# (exang _|_ chol | fbs, heartdisease, thalach, trestbps, restecg, sex)
# (exang _|_ thalach | fbs, heartdisease, chol, age, trestbps, restecg)
# (exang _|_ restecg, thalach | fbs, heartdisease, chol, age, trestbps, sex)
# (exang _|_ thalach | fbs, heartdisease, chol, age, restecg, sex)
# (exang _|_ thalach, chol | fbs, heartdisease, age, trestbps, restecg, sex)
# (exang _|_ thalach | fbs, heartdisease, chol, trestbps, restecg, sex)
# (exang _|_ heartdisease | fbs, thalach, chol, age, trestbps, restecg)
# (exang _|_ heartdisease, restecg | fbs, thalach, chol, age, trestbps, sex)
# (exang _|_ heartdisease, chol | fbs, thalach, age, trestbps, restecg, sex)
# (exang _|_ heartdisease | fbs, thalach, chol, trestbps, restecg, sex)
# (exang _|_ heartdisease, thalach | fbs, chol, age, trestbps, restecg, sex)
# (exang _|_ fbs | heartdisease, thalach, chol, age, trestbps, restecg)
# (exang _|_ fbs, restecg | heartdisease, thalach, chol, age, trestbps, sex)
# (exang _|_ fbs, chol | heartdisease, thalach, age, trestbps, restecg, sex)
# (exang _|_ fbs, thalach | heartdisease, chol, age, trestbps, restecg, sex)
# (exang _|_ fbs, heartdisease | thalach, chol, age, trestbps, restecg, sex)
# (exang _|_ restecg | fbs, heartdisease, thalach, chol, age, trestbps, sex)
# (exang _|_ chol | fbs, heartdisease, thalach, age, trestbps, restecg, sex)
# (exang _|_ thalach | fbs, heartdisease, chol, age, trestbps, restecg, sex)
# (exang _|_ heartdisease | fbs, thalach, chol, age, trestbps, restecg, sex)
# (exang _|_ fbs | heartdisease, thalach, chol, age, trestbps, restecg, sex)
# (heartdisease _|_ sex, exang, age | fbs, trestbps)
# (heartdisease _|_ sex, exang | trestbps, age)
# (heartdisease _|_ sex, exang, age | fbs, thalach, trestbps)
# (heartdisease _|_ sex, exang | fbs, trestbps, age)
# (heartdisease _|_ sex, exang, age | fbs, trestbps, chol)
# (heartdisease _|_ sex, age | fbs, trestbps, exang)
# (heartdisease _|_ sex, exang, age | fbs, restecg, trestbps)
# (heartdisease _|_ exang, age | fbs, sex, trestbps)
# (heartdisease _|_ sex, exang | trestbps, thalach, age)
# (heartdisease _|_ sex, exang | trestbps, chol, age)
# (heartdisease _|_ sex | trestbps, exang, age)
# (heartdisease _|_ sex, exang | restecg, trestbps, age)
# (heartdisease _|_ exang | sex, trestbps, age)
# (heartdisease _|_ sex, exang | fbs, thalach, trestbps, age)
# (heartdisease _|_ sex, exang, age | fbs, thalach, trestbps, chol)
# (heartdisease _|_ sex, age | fbs, thalach, exang, trestbps)
# (heartdisease _|_ sex, exang, age | fbs, restecg, thalach, trestbps)
# (heartdisease _|_ exang, age | fbs, sex, thalach, trestbps)
# (heartdisease _|_ sex, exang | fbs, trestbps, chol, age)
# (heartdisease _|_ sex | fbs, trestbps, exang, age)
# (heartdisease _|_ sex, exang | fbs, restecg, trestbps, age)
# (heartdisease _|_ exang | fbs, sex, trestbps, age)
# (heartdisease _|_ sex, age | fbs, trestbps, exang, chol)
# (heartdisease _|_ sex, exang, age | fbs, restecg, trestbps, chol)
# ...
# (thalach _|_ trestbps, exang, age | fbs, heartdisease, chol, restecg, sex)
# (thalach _|_ age, sex, chol | fbs, heartdisease, trestbps, exang, restecg)
# (thalach _|_ age, restecg, chol | fbs, heartdisease, trestbps, exang, sex)
# (thalach _|_ age, exang, chol | fbs, heartdisease, trestbps, restecg, sex)
# (thalach _|_ age, trestbps, chol | fbs, heartdisease, exang, restecg, sex)
# (thalach _|_ sex | fbs, chol, age, trestbps, exang)
# (thalach _|_ sex, exang | fbs, chol, age, trestbps, restecg)
# (thalach _|_ exang | fbs, chol, age, trestbps, sex)
# (thalach _|_ sex | fbs, age, trestbps, exang, restecg)
# (thalach _|_ exang | fbs, age, trestbps, restecg, sex)
# (thalach _|_ sex, age | fbs, chol, trestbps, exang, restecg)
# (thalach _|_ age | fbs, chol, trestbps, exang, sex)
# (thalach _|_ exang, age | fbs, chol, trestbps, restecg, sex)
# (thalach _|_ age | fbs, trestbps, exang, restecg, sex)
# (thalach _|_ fbs, restecg, sex | heartdisease, chol, age, trestbps, exang)
# (thalach _|_ fbs, sex, exang | heartdisease, chol, age, trestbps, restecg)
# (thalach _|_ fbs, restecg, exang | heartdisease, chol, age, trestbps, sex)
# (thalach _|_ fbs, sex, trestbps | heartdisease, chol, age, exang, restecg)
# (thalach _|_ fbs, restecg, trestbps | heartdisease, chol, age, exang, sex)
# (thalach _|_ fbs, trestbps, exang | heartdisease, chol, age, restecg, sex)
# (thalach _|_ fbs, sex, chol | heartdisease, age, trestbps, exang, restecg)
# (thalach _|_ fbs, restecg, chol | heartdisease, age, trestbps, exang, sex)
# (thalach _|_ fbs, exang, chol | heartdisease, age, trestbps, restecg, sex)
# (thalach _|_ fbs, trestbps, chol | heartdisease, age, exang, restecg, sex)
# (thalach _|_ fbs, sex, age | heartdisease, chol, trestbps, exang, restecg)
# (thalach _|_ fbs, restecg, age | heartdisease, chol, trestbps, exang, sex)
# (thalach _|_ fbs, exang, age | heartdisease, chol, trestbps, restecg, sex)
# (thalach _|_ fbs, trestbps, age | heartdisease, chol, exang, restecg, sex)
# (thalach _|_ fbs, age, chol | heartdisease, trestbps, exang, restecg, sex)
# (thalach _|_ sex | chol, age, trestbps, exang, restecg)
# (thalach _|_ exang | chol, age, trestbps, restecg, sex)
# (thalach _|_ restecg, sex | fbs, heartdisease, chol, age, trestbps, exang)
# (thalach _|_ sex, exang | fbs, heartdisease, chol, age, trestbps, restecg)
# (thalach _|_ restecg, exang | fbs, heartdisease, chol, age, trestbps, sex)
# (thalach _|_ sex, trestbps | fbs, heartdisease, chol, age, exang, restecg)
# (thalach _|_ restecg, trestbps | fbs, heartdisease, chol, age, exang, sex)
# (thalach _|_ trestbps, exang | fbs, heartdisease, chol, age, restecg, sex)
# (thalach _|_ sex, chol | fbs, heartdisease, age, trestbps, exang, restecg)
# (thalach _|_ restecg, chol | fbs, heartdisease, age, trestbps, exang, sex)
# (thalach _|_ exang, chol | fbs, heartdisease, age, trestbps, restecg, sex)
# (thalach _|_ trestbps, chol | fbs, heartdisease, age, exang, restecg, sex)
# (thalach _|_ sex, age | fbs, heartdisease, chol, trestbps, exang, restecg)
# (thalach _|_ restecg, age | fbs, heartdisease, chol, trestbps, exang, sex)
# (thalach _|_ exang, age | fbs, heartdisease, chol, trestbps, restecg, sex)
# (thalach _|_ trestbps, age | fbs, heartdisease, chol, exang, restecg, sex)
# (thalach _|_ age, chol | fbs, heartdisease, trestbps, exang, restecg, sex)
# (thalach _|_ sex | fbs, chol, age, trestbps, exang, restecg)
# (thalach _|_ exang | fbs, chol, age, trestbps, restecg, sex)
# (thalach _|_ age | fbs, chol, trestbps, exang, restecg, sex)
# (thalach _|_ fbs, sex | heartdisease, chol, age, trestbps, exang, restecg)
# (thalach _|_ fbs, restecg | heartdisease, chol, age, trestbps, exang, sex)
# (thalach _|_ fbs, exang | heartdisease, chol, age, trestbps, restecg, sex)
# (thalach _|_ fbs, trestbps | heartdisease, chol, age, exang, restecg, sex)
# (thalach _|_ fbs, chol | heartdisease, age, trestbps, exang, restecg, sex)
# (thalach _|_ fbs, age | heartdisease, chol, trestbps, exang, restecg, sex)
# (thalach _|_ sex | fbs, heartdisease, chol, age, trestbps, exang, restecg)
# (thalach _|_ restecg | fbs, heartdisease, chol, age, trestbps, exang, sex)
# (thalach _|_ exang | fbs, heartdisease, chol, age, trestbps, restecg, sex)
# (thalach _|_ trestbps | fbs, heartdisease, chol, age, exang, restecg, sex)
# (thalach _|_ chol | fbs, heartdisease, age, trestbps, exang, restecg, sex)
# (thalach _|_ age | fbs, heartdisease, chol, trestbps, exang, restecg, sex)
# (thalach _|_ fbs | heartdisease, chol, age, trestbps, exang, restecg, sex)
# (chol _|_ fbs, sex, thalach, exang, age, restecg, trestbps | heartdisease)
# (chol _|_ sex, thalach, exang, age, restecg, trestbps | fbs, heartdisease)
# (chol _|_ sex, exang, age | fbs, trestbps)
# (chol _|_ fbs, sex, exang, age, restecg, trestbps | heartdisease, thalach)
# (chol _|_ fbs, sex, thalach, exang, restecg, trestbps | heartdisease, age)
# (chol _|_ fbs, thalach, exang, age, restecg, sex | heartdisease, trestbps)
# (chol _|_ fbs, sex, thalach, age, restecg, trestbps | heartdisease, exang)
# (chol _|_ fbs, sex, thalach, exang, age, trestbps | heartdisease, restecg)
# (chol _|_ fbs, thalach, exang, age, restecg, trestbps | heartdisease, sex)
# (chol _|_ sex, exang | trestbps, age)
# (chol _|_ sex, exang, age, restecg, trestbps | fbs, heartdisease, thalach)
# (chol _|_ sex, thalach, exang, restecg, trestbps | fbs, heartdisease, age)
# (chol _|_ thalach, exang, age, restecg, sex | fbs, heartdisease, trestbps)
# (chol _|_ sex, thalach, age, restecg, trestbps | fbs, heartdisease, exang)
# (chol _|_ sex, thalach, exang, age, trestbps | fbs, heartdisease, restecg)
# (chol _|_ thalach, exang, age, restecg, trestbps | fbs, heartdisease, sex)
# (chol _|_ sex, exang, age | fbs, thalach, trestbps)
# (chol _|_ sex, exang | fbs, trestbps, age)
# (chol _|_ sex, age | fbs, trestbps, exang)
# (chol _|_ sex, exang, age | fbs, restecg, trestbps)
# (chol _|_ exang, age | fbs, sex, trestbps)
# (chol _|_ fbs, sex, exang, restecg, trestbps | heartdisease, thalach, age)
# (chol _|_ fbs, exang, age, restecg, sex | heartdisease, thalach, trestbps)
# (chol _|_ fbs, sex, age, restecg, trestbps | heartdisease, thalach, exang)
# (chol _|_ fbs, sex, exang, age, trestbps | heartdisease, restecg, thalach)
# (chol _|_ fbs, exang, age, restecg, trestbps | heartdisease, sex, thalach)
# (chol _|_ fbs, thalach, exang, restecg, sex | heartdisease, trestbps, age)
# (chol _|_ fbs, sex, thalach, restecg, trestbps | heartdisease, exang, age)
# (chol _|_ fbs, sex, thalach, exang, trestbps | heartdisease, restecg, age)
# (chol _|_ fbs, thalach, exang, restecg, trestbps | heartdisease, sex, age)
# (chol _|_ fbs, thalach, age, restecg, sex | heartdisease, trestbps, exang)
# (chol _|_ fbs, thalach, exang, age, sex | heartdisease, restecg, trestbps)
# (chol _|_ fbs, thalach, exang, age, restecg | heartdisease, sex, trestbps)
# (chol _|_ fbs, sex, thalach, age, trestbps | heartdisease, restecg, exang)
# (chol _|_ fbs, thalach, age, restecg, trestbps | heartdisease, sex, exang)
# (chol _|_ fbs, thalach, exang, age, trestbps | heartdisease, restecg, sex)
# (chol _|_ sex, exang | trestbps, thalach, age)
# (chol _|_ sex | trestbps, exang, age)
# (chol _|_ sex, exang | restecg, trestbps, age)
# (chol _|_ exang | sex, trestbps, age)
# (chol _|_ restecg, sex, exang, trestbps | fbs, heartdisease, thalach, age)
# (chol _|_ restecg, sex, exang, age | fbs, heartdisease, thalach, trestbps)
# (chol _|_ age, restecg, sex, trestbps | fbs, heartdisease, thalach, exang)
# (chol _|_ age, sex, exang, trestbps | fbs, heartdisease, restecg, thalach)
# (chol _|_ restecg, trestbps, exang, age | fbs, sex, heartdisease, thalach)
# (chol _|_ restecg, exang, sex, thalach | fbs, heartdisease, trestbps, age)
# (chol _|_ restecg, sex, thalach, trestbps | fbs, heartdisease, exang, age)
# (chol _|_ thalach, sex, exang, trestbps | fbs, heartdisease, restecg, age)
# (chol _|_ restecg, thalach, exang, trestbps | fbs, heartdisease, sex, age)
# (chol _|_ restecg, sex, thalach, age | fbs, heartdisease, trestbps, exang)
# (chol _|_ thalach, sex, exang, age | fbs, heartdisease, restecg, trestbps)
# (chol _|_ restecg, thalach, exang, age | fbs, sex, heartdisease, trestbps)
# (chol _|_ sex, thalach, trestbps, age | fbs, heartdisease, restecg, exang)
# (chol _|_ restecg, trestbps, thalach, age | fbs, sex, heartdisease, exang)
# (chol _|_ thalach, trestbps, exang, age | fbs, heartdisease, restecg, sex)
# (chol _|_ sex, exang | fbs, thalach, trestbps, age)
# (chol _|_ sex, age | fbs, thalach, exang, trestbps)
# (chol _|_ sex, exang, age | fbs, restecg, thalach, trestbps)
# (chol _|_ exang, age | fbs, sex, thalach, trestbps)
# (chol _|_ sex | fbs, trestbps, exang, age)
# (chol _|_ sex, exang | fbs, restecg, trestbps, age)
# (chol _|_ exang | fbs, sex, trestbps, age)
# (chol _|_ sex, age | fbs, restecg, trestbps, exang)
# (chol _|_ age | fbs, sex, trestbps, exang)
# (chol _|_ exang, age | fbs, sex, restecg, trestbps)
# (chol _|_ fbs, restecg, sex, exang | heartdisease, thalach, trestbps, age)
# (chol _|_ fbs, restecg, sex, trestbps | heartdisease, thalach, exang, age)
# (chol _|_ fbs, sex, exang, trestbps | heartdisease, restecg, thalach, age)
# (chol _|_ fbs, restecg, trestbps, exang | heartdisease, sex, thalach, age)
# (chol _|_ fbs, restecg, sex, age | heartdisease, thalach, exang, trestbps)
# (chol _|_ fbs, sex, exang, age | heartdisease, restecg, thalach, trestbps)
# (chol _|_ fbs, restecg, exang, age | heartdisease, sex, thalach, trestbps)
# (chol _|_ fbs, age, sex, trestbps | heartdisease, restecg, thalach, exang)
# (chol _|_ fbs, restecg, trestbps, age | heartdisease, sex, thalach, exang)
# (chol _|_ fbs, trestbps, exang, age | heartdisease, sex, restecg, thalach)
# (chol _|_ fbs, restecg, sex, thalach | heartdisease, trestbps, exang, age)
# (chol _|_ fbs, thalach, sex, exang | heartdisease, restecg, trestbps, age)
# (chol _|_ fbs, restecg, thalach, exang | heartdisease, sex, trestbps, age)
# (chol _|_ fbs, thalach, sex, trestbps | heartdisease, restecg, exang, age)
# (chol _|_ fbs, restecg, thalach, trestbps | heartdisease, sex, exang, age)
# (chol _|_ fbs, thalach, exang, trestbps | heartdisease, restecg, sex, age)
# (chol _|_ fbs, thalach, sex, age | heartdisease, restecg, trestbps, exang)
# (chol _|_ fbs, restecg, thalach, age | heartdisease, sex, trestbps, exang)
# (chol _|_ fbs, thalach, exang, age | heartdisease, sex, restecg, trestbps)
# (chol _|_ fbs, age, thalach, trestbps | heartdisease, sex, restecg, exang)
# (chol _|_ sex | trestbps, thalach, exang, age)
# (chol _|_ sex, exang | trestbps, restecg, thalach, age)
# (chol _|_ exang | trestbps, sex, thalach, age)
# (chol _|_ sex | restecg, trestbps, exang, age)
# (chol _|_ exang | sex, restecg, trestbps, age)
# (chol _|_ restecg, sex, exang | fbs, heartdisease, thalach, age, trestbps)
# (chol _|_ restecg, sex, trestbps | fbs, heartdisease, thalach, age, exang)
# (chol _|_ sex, exang, trestbps | fbs, heartdisease, thalach, age, restecg)
# (chol _|_ restecg, trestbps, exang | fbs, heartdisease, thalach, age, sex)
# (chol _|_ restecg, sex, age | fbs, heartdisease, thalach, trestbps, exang)
# (chol _|_ sex, exang, age | fbs, heartdisease, thalach, trestbps, restecg)
# (chol _|_ restecg, exang, age | fbs, heartdisease, thalach, trestbps, sex)
# (chol _|_ age, sex, trestbps | fbs, heartdisease, thalach, exang, restecg)
# (chol _|_ restecg, trestbps, age | fbs, heartdisease, thalach, exang, sex)
# (chol _|_ trestbps, exang, age | fbs, heartdisease, thalach, restecg, sex)
# (chol _|_ restecg, sex, thalach | fbs, heartdisease, age, trestbps, exang)
# (chol _|_ thalach, sex, exang | fbs, heartdisease, age, trestbps, restecg)
# (chol _|_ restecg, thalach, exang | fbs, heartdisease, age, trestbps, sex)
# (chol _|_ thalach, sex, trestbps | fbs, heartdisease, age, exang, restecg)
# (chol _|_ restecg, thalach, trestbps | fbs, heartdisease, age, exang, sex)
# (chol _|_ thalach, exang, trestbps | fbs, heartdisease, age, restecg, sex)
# (chol _|_ thalach, sex, age | fbs, heartdisease, trestbps, exang, restecg)
# (chol _|_ restecg, thalach, age | fbs, heartdisease, trestbps, exang, sex)
# (chol _|_ thalach, exang, age | fbs, heartdisease, trestbps, restecg, sex)
# (chol _|_ thalach, trestbps, age | fbs, heartdisease, exang, restecg, sex)
# (chol _|_ sex | fbs, thalach, age, trestbps, exang)
# (chol _|_ sex, exang | fbs, thalach, age, trestbps, restecg)
# (chol _|_ exang | fbs, thalach, age, trestbps, sex)
# (chol _|_ sex, age | fbs, thalach, trestbps, exang, restecg)
# (chol _|_ age | fbs, thalach, trestbps, exang, sex)
# (chol _|_ exang, age | fbs, thalach, trestbps, restecg, sex)
# (chol _|_ sex | fbs, age, trestbps, exang, restecg)
# (chol _|_ exang | fbs, age, trestbps, restecg, sex)
# (chol _|_ age | fbs, trestbps, exang, restecg, sex)
# (chol _|_ fbs, restecg, sex | heartdisease, thalach, age, trestbps, exang)
# (chol _|_ fbs, sex, exang | heartdisease, thalach, age, trestbps, restecg)
# (chol _|_ fbs, restecg, exang | heartdisease, thalach, age, trestbps, sex)
# (chol _|_ fbs, sex, trestbps | heartdisease, thalach, age, exang, restecg)
# (chol _|_ fbs, restecg, trestbps | heartdisease, thalach, age, exang, sex)
# (chol _|_ fbs, trestbps, exang | heartdisease, thalach, age, restecg, sex)
# (chol _|_ fbs, sex, age | heartdisease, thalach, trestbps, exang, restecg)
# (chol _|_ fbs, restecg, age | heartdisease, thalach, trestbps, exang, sex)
# (chol _|_ fbs, exang, age | heartdisease, thalach, trestbps, restecg, sex)
# (chol _|_ fbs, trestbps, age | heartdisease, thalach, exang, restecg, sex)
# (chol _|_ fbs, thalach, sex | heartdisease, age, trestbps, exang, restecg)
# (chol _|_ fbs, restecg, thalach | heartdisease, age, trestbps, exang, sex)
# (chol _|_ fbs, thalach, exang | heartdisease, age, trestbps, restecg, sex)
# (chol _|_ fbs, thalach, trestbps | heartdisease, age, exang, restecg, sex)
# (chol _|_ fbs, thalach, age | heartdisease, trestbps, exang, restecg, sex)
# (chol _|_ sex | thalach, age, trestbps, exang, restecg)
# (chol _|_ exang | thalach, age, trestbps, restecg, sex)
# (chol _|_ restecg, sex | fbs, heartdisease, thalach, age, trestbps, exang)
# (chol _|_ sex, exang | fbs, heartdisease, thalach, age, trestbps, restecg)
# (chol _|_ restecg, exang | fbs, heartdisease, thalach, age, trestbps, sex)
# (chol _|_ sex, trestbps | fbs, heartdisease, thalach, age, exang, restecg)
# (chol _|_ restecg, trestbps | fbs, heartdisease, thalach, age, exang, sex)
# (chol _|_ trestbps, exang | fbs, heartdisease, thalach, age, restecg, sex)
# (chol _|_ sex, age | fbs, heartdisease, thalach, trestbps, exang, restecg)
# (chol _|_ restecg, age | fbs, heartdisease, thalach, trestbps, exang, sex)
# (chol _|_ exang, age | fbs, heartdisease, thalach, trestbps, restecg, sex)
# (chol _|_ trestbps, age | fbs, heartdisease, thalach, exang, restecg, sex)
# (chol _|_ thalach, sex | fbs, heartdisease, age, trestbps, exang, restecg)
# (chol _|_ restecg, thalach | fbs, heartdisease, age, trestbps, exang, sex)
# (chol _|_ thalach, exang | fbs, heartdisease, age, trestbps, restecg, sex)
# (chol _|_ thalach, trestbps | fbs, heartdisease, age, exang, restecg, sex)
# (chol _|_ thalach, age | fbs, heartdisease, trestbps, exang, restecg, sex)
# (chol _|_ sex | fbs, thalach, age, trestbps, exang, restecg)
# (chol _|_ exang | fbs, thalach, age, trestbps, restecg, sex)
# (chol _|_ age | fbs, thalach, trestbps, exang, restecg, sex)
# (chol _|_ fbs, sex | heartdisease, thalach, age, trestbps, exang, restecg)
# (chol _|_ fbs, restecg | heartdisease, thalach, age, trestbps, exang, sex)
# (chol _|_ fbs, exang | heartdisease, thalach, age, trestbps, restecg, sex)
# (chol _|_ fbs, trestbps | heartdisease, thalach, age, exang, restecg, sex)
# (chol _|_ fbs, age | heartdisease, thalach, trestbps, exang, restecg, sex)
# (chol _|_ fbs, thalach | heartdisease, age, trestbps, exang, restecg, sex)
# (chol _|_ sex | fbs, heartdisease, thalach, age, trestbps, exang, restecg)
# (chol _|_ restecg | fbs, heartdisease, thalach, age, trestbps, exang, sex)
# (chol _|_ exang | fbs, heartdisease, thalach, age, trestbps, restecg, sex)
# (chol _|_ trestbps | fbs, heartdisease, thalach, age, exang, restecg, sex)
# (chol _|_ age | fbs, heartdisease, thalach, trestbps, exang, restecg, sex)
# (chol _|_ thalach | fbs, heartdisease, age, trestbps, exang, restecg, sex)
# (chol _|_ fbs | heartdisease, thalach, age, trestbps, exang, restecg, sex)

# %%
from pgmpy.inference import VariableElimination
HeartDisease_infer = VariableElimination(model)

q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 28})
print(q['heartdisease'])
# Out:
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              0.5770 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.4230 │
# ╘════════════════╧═════════════════════╛
# c:\users\harsh\appdata\local\programs\python\python37\lib\site-packages\pgmpy\factors\discrete\DiscreteFactor.py:586: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi.values = phi.values[slice_]
# c:\users\harsh\appdata\local\programs\python\python37\lib\site-packages\pgmpy\factors\discrete\DiscreteFactor.py:598: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi1.values = phi1.values[slice_]

# %%
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'chol': 100})
print(q['heartdisease'])
# Out:
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              0.5510 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.4490 │
# ╘════════════════╧═════════════════════╛
